# %%
# Import Dep.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# zip to combine lats and lngs into a single iterator object
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use list() to transform the iterator object into a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    # Loop through all the cities in the list.
for i, city in enumerate(cities):

        # Group cities in sets of 50 for logging purposes.
        if (i % 50 == 0 and i >= 50):
            set_count += 1
            record_count = 1
            time.sleep(60)

        # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")
        
        # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        
        # Add 1 to the record count.
        record_count += 1

        # Run an API request for each of the cities.
        try:
            # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
            # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            
            # weather contains one list, description is stored in this list
            city_description = city_weather["weather"][0]["description"]
            
            city_country = city_weather["sys"]["country"]
            
            # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_description,
                              "Country": city_country})

     #If an error is experienced, skip the city.
        except:
            print("City not found. Skipping...")
            pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | afsin
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | esperance
# Processing Record 4 of Set 1 | tuchola
# Processing Record 5 of Set 1 | tuatapere
# Processing Record 6 of Set 1 | beloha
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | khani
# Processing Record 9 of Set 1 | churapcha
# Processing Record 10 of Set 1 | richards bay
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 1 | upernavik
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | kaeo
# Processing Record 16 of Set 1 | korla
# Processing Record 17 of Set 1 | aberdeen
# Processing Record 18 of Set 1 | hobart
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | narsaq
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | meulaboh
# Processing Record 26 of Set 1 | mazyr
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | swan river
# Processing Record 31 of Set 1 | westport
# Processing Record 32 of Set 1 | saint-louis
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | codrington
# Processing Record 35 of Set 1 | kamenka
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | vila franca do campo
# Processing Record 38 of Set 1 | kavaratti
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | saldanha
# Processing Record 41 of Set 1 | vangaindrano
# Processing Record 42 of Set 1 | tigil
# Processing Record 43 of Set 1 | udachnyy
# Processing Record 44 of Set 1 | kavieng
# Processing Record 45 of Set 1 | shimoda
# Processing Record 46 of Set 1 | falmouth
# Processing Record 47 of Set 1 | grimari
# City not found. Skipping...
# Processing Record 48 of Set 1 | calabozo
# Processing Record 49 of Set 1 | calvinia
# Processing Record 50 of Set 1 | labuhan
# Processing Record 1 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 2 | vaitape
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | castro
# Processing Record 5 of Set 2 | razdolnoye
# Processing Record 6 of Set 2 | ahipara
# Processing Record 7 of Set 2 | hami
# Processing Record 8 of Set 2 | naze
# Processing Record 9 of Set 2 | viedma
# Processing Record 10 of Set 2 | sfantu gheorghe
# Processing Record 11 of Set 2 | arti
# Processing Record 12 of Set 2 | manta
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | olden
# Processing Record 15 of Set 2 | chokurdakh
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | tambo
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | coquimbo
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | gazli
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | bathsheba
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | ponta do sol
# Processing Record 29 of Set 2 | port hardy
# Processing Record 30 of Set 2 | pacific grove
# Processing Record 31 of Set 2 | memaliaj
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | ustyuzhna
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | nikolskoye
# Processing Record 36 of Set 2 | savinka
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | soyo
# Processing Record 39 of Set 2 | tual
# Processing Record 40 of Set 2 | pareora
# Processing Record 41 of Set 2 | vicuna
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | yinchuan
# Processing Record 44 of Set 2 | la trinidad
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | muzhi
# Processing Record 47 of Set 2 | pochutla
# Processing Record 48 of Set 2 | kruisfontein
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | axim
# Processing Record 3 of Set 3 | aliwal north
# Processing Record 4 of Set 3 | sur
# Processing Record 5 of Set 3 | hermanus
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | tezu
# Processing Record 10 of Set 3 | moerai
# Processing Record 11 of Set 3 | baykit
# Processing Record 12 of Set 3 | concarneau
# Processing Record 13 of Set 3 | karema
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | nome
# Processing Record 17 of Set 3 | bengkulu
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | lebu
# Processing Record 20 of Set 3 | khatanga
# Processing Record 21 of Set 3 | otradnoye
# Processing Record 22 of Set 3 | high level
# Processing Record 23 of Set 3 | port elizabeth
# Processing Record 24 of Set 3 | comodoro rivadavia
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | nara
# Processing Record 27 of Set 3 | mar del plata
# Processing Record 28 of Set 3 | dikson
# Processing Record 29 of Set 3 | touros
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 3 | egvekinot
# Processing Record 34 of Set 3 | anchorage
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 38 of Set 3 | lasa
# Processing Record 39 of Set 3 | miranda
# Processing Record 40 of Set 3 | padang
# Processing Record 41 of Set 3 | kaitangata
# Processing Record 42 of Set 3 | campbell river
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | sola
# Processing Record 45 of Set 3 | klaksvik
# Processing Record 46 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 47 of Set 3 | green river
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | te anau
# Processing Record 50 of Set 3 | coahuayana
# Processing Record 1 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | tiksi
# Processing Record 3 of Set 4 | koslan
# Processing Record 4 of Set 4 | port blair
# Processing Record 5 of Set 4 | santa maria
# Processing Record 6 of Set 4 | turan
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | mao
# Processing Record 9 of Set 4 | platanos
# Processing Record 10 of Set 4 | cleethorpes
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | ararat
# Processing Record 13 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 4 | kalaleh
# Processing Record 15 of Set 4 | kralendijk
# Processing Record 16 of Set 4 | qaanaaq
# Processing Record 17 of Set 4 | moju
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | pedro juan caballero
# Processing Record 20 of Set 4 | povenets
# Processing Record 21 of Set 4 | portland
# Processing Record 22 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 4 | mut
# Processing Record 24 of Set 4 | itaobim
# Processing Record 25 of Set 4 | dawlatabad
# Processing Record 26 of Set 4 | havoysund
# Processing Record 27 of Set 4 | arenal
# Processing Record 28 of Set 4 | hasaki
# Processing Record 29 of Set 4 | tsabong
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | limbang
# Processing Record 33 of Set 4 | moron
# Processing Record 34 of Set 4 | christchurch
# Processing Record 35 of Set 4 | broken hill
# Processing Record 36 of Set 4 | carutapera
# Processing Record 37 of Set 4 | russell
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | mana
# Processing Record 40 of Set 4 | vanino
# Processing Record 41 of Set 4 | rincon
# Processing Record 42 of Set 4 | diamantina
# Processing Record 43 of Set 4 | lexington
# Processing Record 44 of Set 4 | beeville
# Processing Record 45 of Set 4 | bluff
# Processing Record 46 of Set 4 | lorengau
# Processing Record 47 of Set 4 | samandag
# Processing Record 48 of Set 4 | shingu
# Processing Record 49 of Set 4 | chicama
# Processing Record 50 of Set 4 | sijunjung
# Processing Record 1 of Set 5 | ponta delgada
# Processing Record 2 of Set 5 | palmer
# Processing Record 3 of Set 5 | longyearbyen
# Processing Record 4 of Set 5 | maltahohe
# Processing Record 5 of Set 5 | danjiangkou
# Processing Record 6 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 7 of Set 5 | urumqi
# Processing Record 8 of Set 5 | west wendover
# Processing Record 9 of Set 5 | corinto
# Processing Record 10 of Set 5 | bilibino
# Processing Record 11 of Set 5 | antofagasta
# Processing Record 12 of Set 5 | mackay
# Processing Record 13 of Set 5 | asyut
# Processing Record 14 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | port macquarie
# Processing Record 17 of Set 5 | porvoo
# Processing Record 18 of Set 5 | kendari
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | tasiilaq
# Processing Record 21 of Set 5 | bend
# Processing Record 22 of Set 5 | la ronge
# Processing Record 23 of Set 5 | yaan
# Processing Record 24 of Set 5 | yerbogachen
# Processing Record 25 of Set 5 | cape coast
# Processing Record 26 of Set 5 | blythe
# Processing Record 27 of Set 5 | joshimath
# Processing Record 28 of Set 5 | awbari
# Processing Record 29 of Set 5 | luanda
# Processing Record 30 of Set 5 | brovst
# Processing Record 31 of Set 5 | mtimbira
# Processing Record 32 of Set 5 | iqaluit
# Processing Record 33 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 5 | taoudenni
# Processing Record 35 of Set 5 | doka
# Processing Record 36 of Set 5 | suclayin
# Processing Record 37 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 38 of Set 5 | eureka
# Processing Record 39 of Set 5 | bridlington
# Processing Record 40 of Set 5 | plettenberg bay
# Processing Record 41 of Set 5 | sanchor
# Processing Record 42 of Set 5 | sobolevo
# Processing Record 43 of Set 5 | tagpangi
# City not found. Skipping...
# Processing Record 44 of Set 5 | pangnirtung
# Processing Record 45 of Set 5 | rio cuarto
# Processing Record 46 of Set 5 | lingdong
# Processing Record 47 of Set 5 | corrales
# Processing Record 48 of Set 5 | maralal
# Processing Record 49 of Set 5 | faanui
# Processing Record 50 of Set 5 | wolgast
# Processing Record 1 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | seoni
# Processing Record 3 of Set 6 | saint-georges
# Processing Record 4 of Set 6 | waingapu
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | porto novo
# Processing Record 7 of Set 6 | kindu
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | zalantun
# Processing Record 10 of Set 6 | luang prabang
# Processing Record 11 of Set 6 | sao filipe
# Processing Record 12 of Set 6 | jumla
# Processing Record 13 of Set 6 | carsamba
# Processing Record 14 of Set 6 | bakchar
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | qaqortoq
# Processing Record 17 of Set 6 | yar-sale
# Processing Record 18 of Set 6 | tautira
# Processing Record 19 of Set 6 | caravelas
# Processing Record 20 of Set 6 | mayo
# Processing Record 21 of Set 6 | celestun
# Processing Record 22 of Set 6 | yelovo
# Processing Record 23 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 6 | revelstoke
# Processing Record 25 of Set 6 | agadez
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | ust-nera
# Processing Record 28 of Set 6 | nishihara
# Processing Record 29 of Set 6 | pimentel
# Processing Record 30 of Set 6 | haines junction
# Processing Record 31 of Set 6 | nizwa
# Processing Record 32 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 6 | husavik
# Processing Record 34 of Set 6 | san cristobal
# Processing Record 35 of Set 6 | savalou
# Processing Record 36 of Set 6 | broome
# Processing Record 37 of Set 6 | roi et
# Processing Record 38 of Set 6 | alihe
# Processing Record 39 of Set 6 | ballina
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | mehamn
# Processing Record 42 of Set 6 | hovd
# Processing Record 43 of Set 6 | caarapo
# Processing Record 44 of Set 6 | bochov
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | alice springs
# Processing Record 47 of Set 6 | sibolga
# Processing Record 48 of Set 6 | ozinki
# Processing Record 49 of Set 6 | bryukhovychi
# Processing Record 50 of Set 6 | marsa matruh
# Processing Record 1 of Set 7 | luderitz
# Processing Record 2 of Set 7 | ekibastuz
# Processing Record 3 of Set 7 | geraldton
# Processing Record 4 of Set 7 | talnakh
# Processing Record 5 of Set 7 | mexico
# Processing Record 6 of Set 7 | sioux lookout
# Processing Record 7 of Set 7 | chiredzi
# Processing Record 8 of Set 7 | tommot
# Processing Record 9 of Set 7 | songjianghe
# Processing Record 10 of Set 7 | kupang
# Processing Record 11 of Set 7 | botwood
# Processing Record 12 of Set 7 | binzhou
# Processing Record 13 of Set 7 | pokhara
# Processing Record 14 of Set 7 | ca mau
# Processing Record 15 of Set 7 | hokitika
# Processing Record 16 of Set 7 | bethel
# Processing Record 17 of Set 7 | qui nhon
# Processing Record 18 of Set 7 | kadaya
# Processing Record 19 of Set 7 | vestmannaeyjar
# Processing Record 20 of Set 7 | peoria
# Processing Record 21 of Set 7 | samarai
# Processing Record 22 of Set 7 | guerrero negro
# Processing Record 23 of Set 7 | springdale
# Processing Record 24 of Set 7 | lahat
# Processing Record 25 of Set 7 | zajas
# Processing Record 26 of Set 7 | bukachacha
# Processing Record 27 of Set 7 | hirara
# Processing Record 28 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 7 | santa cruz
# Processing Record 30 of Set 7 | gursu
# Processing Record 31 of Set 7 | the valley
# Processing Record 32 of Set 7 | ahuimanu
# Processing Record 33 of Set 7 | charthawal
# Processing Record 34 of Set 7 | airai
# Processing Record 35 of Set 7 | shalya
# Processing Record 36 of Set 7 | satinka
# Processing Record 37 of Set 7 | taree
# Processing Record 38 of Set 7 | petatlan
# Processing Record 39 of Set 7 | princeton
# Processing Record 40 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 7 | usogorsk
# Processing Record 43 of Set 7 | nabire
# Processing Record 44 of Set 7 | dzhebariki-khaya
# Processing Record 45 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 7 | tura
# Processing Record 47 of Set 7 | quelimane
# Processing Record 48 of Set 7 | brits
# Processing Record 49 of Set 7 | leona vicario
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | clyde river
# Processing Record 2 of Set 8 | talcahuano
# Processing Record 3 of Set 8 | rocha
# Processing Record 4 of Set 8 | rassvet
# Processing Record 5 of Set 8 | faya
# Processing Record 6 of Set 8 | fort nelson
# Processing Record 7 of Set 8 | axixa do tocantins
# City not found. Skipping...
# Processing Record 8 of Set 8 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 9 of Set 8 | dubbo
# Processing Record 10 of Set 8 | moshny
# Processing Record 11 of Set 8 | alta floresta
# Processing Record 12 of Set 8 | hamilton
# Processing Record 13 of Set 8 | champerico
# Processing Record 14 of Set 8 | arica
# Processing Record 15 of Set 8 | gat
# Processing Record 16 of Set 8 | dhidhdhoo
# Processing Record 17 of Set 8 | shelby
# Processing Record 18 of Set 8 | newport
# Processing Record 19 of Set 8 | arys
# Processing Record 20 of Set 8 | sisimiut
# Processing Record 21 of Set 8 | tazovskiy
# Processing Record 22 of Set 8 | la carolina
# Processing Record 23 of Set 8 | abonnema
# Processing Record 24 of Set 8 | bandar-e lengeh
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | loubomo
# Processing Record 27 of Set 8 | camacha
# Processing Record 28 of Set 8 | gigmoto
# Processing Record 29 of Set 8 | chilca
# Processing Record 30 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 8 | sakakah
# Processing Record 32 of Set 8 | santo antonio do ica
# Processing Record 33 of Set 8 | torrington
# Processing Record 34 of Set 8 | pemangkat
# Processing Record 35 of Set 8 | biu
# Processing Record 36 of Set 8 | andenes
# Processing Record 37 of Set 8 | grand-santi
# Processing Record 38 of Set 8 | katsuura
# Processing Record 39 of Set 8 | menzelinsk
# Processing Record 40 of Set 8 | rio gallegos
# Processing Record 41 of Set 8 | leh
# Processing Record 42 of Set 8 | mataram
# Processing Record 43 of Set 8 | tomatlan
# Processing Record 44 of Set 8 | northam
# Processing Record 45 of Set 8 | namatanai
# Processing Record 46 of Set 8 | uyuni
# Processing Record 47 of Set 8 | pasinler
# Processing Record 48 of Set 8 | beisfjord
# Processing Record 49 of Set 8 | laguna
# Processing Record 50 of Set 8 | piacabucu
# Processing Record 1 of Set 9 | nola
# Processing Record 2 of Set 9 | khandyga
# Processing Record 3 of Set 9 | half moon bay
# Processing Record 4 of Set 9 | terbuny
# Processing Record 5 of Set 9 | diamantino
# Processing Record 6 of Set 9 | dunedin
# Processing Record 7 of Set 9 | kawalu
# Processing Record 8 of Set 9 | marsh harbour
# Processing Record 9 of Set 9 | vardo
# Processing Record 10 of Set 9 | arraial do cabo
# Processing Record 11 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 9 | north bend
# Processing Record 13 of Set 9 | kandrian
# Processing Record 14 of Set 9 | grudziadz
# Processing Record 15 of Set 9 | urucui
# Processing Record 16 of Set 9 | novikovo
# Processing Record 17 of Set 9 | kentau
# Processing Record 18 of Set 9 | vostok
# Processing Record 19 of Set 9 | kaduy
# Processing Record 20 of Set 9 | vila velha
# Processing Record 21 of Set 9 | rexburg
# Processing Record 22 of Set 9 | lamesa
# Processing Record 23 of Set 9 | bandipur
# Processing Record 24 of Set 9 | west calder
# Processing Record 25 of Set 9 | sicamous
# Processing Record 26 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 9 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 9 | la asuncion
# Processing Record 29 of Set 9 | nurota
# Processing Record 30 of Set 9 | maningrida
# Processing Record 31 of Set 9 | berikulskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | sitka
# Processing Record 33 of Set 9 | saint-pierre
# Processing Record 34 of Set 9 | kabalo
# Processing Record 35 of Set 9 | eyl
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | cockburn town
# Processing Record 38 of Set 9 | north myrtle beach
# Processing Record 39 of Set 9 | fairbanks
# Processing Record 40 of Set 9 | cabras
# Processing Record 41 of Set 9 | casablanca
# Processing Record 42 of Set 9 | jonkoping
# Processing Record 43 of Set 9 | durant
# Processing Record 44 of Set 9 | yulara
# Processing Record 45 of Set 9 | cidreira
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | nanded
# City not found. Skipping...
# Processing Record 48 of Set 9 | maumere
# Processing Record 49 of Set 9 | parabel
# Processing Record 50 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 1 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 10 | busko-zdroj
# Processing Record 3 of Set 10 | prigorodnyy
# Processing Record 4 of Set 10 | berdigestyakh
# Processing Record 5 of Set 10 | okhotsk
# Processing Record 6 of Set 10 | ambulu
# Processing Record 7 of Set 10 | nelson bay
# Processing Record 8 of Set 10 | tuktoyaktuk
# Processing Record 9 of Set 10 | aswan
# Processing Record 10 of Set 10 | nuuk
# Processing Record 11 of Set 10 | rio grande
# Processing Record 12 of Set 10 | atar
# Processing Record 13 of Set 10 | krasnodon
# Processing Record 14 of Set 10 | mareeba
# Processing Record 15 of Set 10 | atasu
# Processing Record 16 of Set 10 | hofn
# Processing Record 17 of Set 10 | aklavik
# Processing Record 18 of Set 10 | tevriz
# Processing Record 19 of Set 10 | tabou
# Processing Record 20 of Set 10 | slavyanka
# Processing Record 21 of Set 10 | morondava
# Processing Record 22 of Set 10 | tabuk
# Processing Record 23 of Set 10 | badulla
# Processing Record 24 of Set 10 | port lincoln
# Processing Record 25 of Set 10 | nioro
# Processing Record 26 of Set 10 | rezekne
# Processing Record 27 of Set 10 | vao
# Processing Record 28 of Set 10 | podares
# Processing Record 29 of Set 10 | kuching
# Processing Record 30 of Set 10 | ilulissat
# Processing Record 31 of Set 10 | dingle
# Processing Record 32 of Set 10 | ippy
# Processing Record 33 of Set 10 | san andres
# Processing Record 34 of Set 10 | ketchikan
# Processing Record 35 of Set 10 | lagos
# Processing Record 36 of Set 10 | labuan
# Processing Record 37 of Set 10 | curitibanos
# Processing Record 38 of Set 10 | upington
# Processing Record 39 of Set 10 | jalu
# Processing Record 40 of Set 10 | santa rosa
# Processing Record 41 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 42 of Set 10 | kargasok
# Processing Record 43 of Set 10 | tsentralnyy
# City not found. Skipping...
# Processing Record 44 of Set 10 | saint anthony
# Processing Record 45 of Set 10 | podor
# Processing Record 46 of Set 10 | sedalia
# Processing Record 47 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 48 of Set 10 | hay river
# Processing Record 49 of Set 10 | mananjary
# Processing Record 50 of Set 10 | atambua
# Processing Record 1 of Set 11 | alto araguaia
# Processing Record 2 of Set 11 | zeya
# Processing Record 3 of Set 11 | zhigansk
# Processing Record 4 of Set 11 | zheleznodorozhnyy
# Processing Record 5 of Set 11 | chapais
# Processing Record 6 of Set 11 | pitea
# Processing Record 7 of Set 11 | barda
# Processing Record 8 of Set 11 | fuerte olimpo
# Processing Record 9 of Set 11 | rosetta
# Processing Record 10 of Set 11 | aksu
# Processing Record 11 of Set 11 | kosa
# Processing Record 12 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 11 | kiruna
# Processing Record 14 of Set 11 | umea
# Processing Record 15 of Set 11 | terme
# Processing Record 16 of Set 11 | sylacauga
# Processing Record 17 of Set 11 | ojinaga
# Processing Record 18 of Set 11 | starosubkhangulovo
# Processing Record 19 of Set 11 | pingxiang
# Processing Record 20 of Set 11 | bitkine
# Processing Record 21 of Set 11 | cabra
# Processing Record 22 of Set 11 | mantua
# Processing Record 23 of Set 11 | nantucket
# Processing Record 24 of Set 11 | bayonet point
# Processing Record 25 of Set 11 | kandi
# Processing Record 26 of Set 11 | tilichiki
# Processing Record 27 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 11 | trairi
# Processing Record 29 of Set 11 | tiruchchendur
# Processing Record 30 of Set 11 | asfi
# Processing Record 31 of Set 11 | angoche
# Processing Record 32 of Set 11 | am timan
# Processing Record 33 of Set 11 | chernyshevskiy
# Processing Record 34 of Set 11 | albanel
# Processing Record 35 of Set 11 | grand gaube
# Processing Record 36 of Set 11 | hays
# Processing Record 37 of Set 11 | klichka
# Processing Record 38 of Set 11 | bustamante
# Processing Record 39 of Set 11 | manokwari
# Processing Record 40 of Set 11 | ayr
# Processing Record 41 of Set 11 | coolum beach
# Processing Record 42 of Set 11 | araouane
# Processing Record 43 of Set 11 | xixiang
# Processing Record 44 of Set 11 | makakilo city
# Processing Record 45 of Set 11 | lianzhou
# Processing Record 46 of Set 11 | general roca
# Processing Record 47 of Set 11 | zyryanovskiy
# City not found. Skipping...
# Processing Record 48 of Set 11 | kalmunai
# Processing Record 49 of Set 11 | krasnoselkup
# Processing Record 50 of Set 11 | chumikan
# Processing Record 1 of Set 12 | camargo
# Processing Record 2 of Set 12 | figeac
# Processing Record 3 of Set 12 | kapoeta
# Processing Record 4 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 12 | akyab
# Processing Record 6 of Set 12 | hambantota
# Processing Record 7 of Set 12 | burgersdorp
# Processing Record 8 of Set 12 | nemuro
# Processing Record 9 of Set 12 | paamiut
# Processing Record 10 of Set 12 | santa helena de goias
# Processing Record 11 of Set 12 | roseburg
# Processing Record 12 of Set 12 | merauke
# Processing Record 13 of Set 12 | trn
# Processing Record 14 of Set 12 | kahului
# Processing Record 15 of Set 12 | xining
# Processing Record 16 of Set 12 | salto de pirapora
# Processing Record 17 of Set 12 | tuy hoa
# Processing Record 18 of Set 12 | spornoye
# Processing Record 19 of Set 12 | verkhnevilyuysk
# Processing Record 20 of Set 12 | manicore
# Processing Record 21 of Set 12 | hualmay
# Processing Record 22 of Set 12 | bandarbeyla
# Processing Record 23 of Set 12 | buala
# Processing Record 24 of Set 12 | homer
# Processing Record 25 of Set 12 | candido mendes
# Processing Record 26 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 27 of Set 12 | talaya
# Processing Record 28 of Set 12 | kieta
# Processing Record 29 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 12 | wahpeton
# Processing Record 31 of Set 12 | kattivakkam
# Processing Record 32 of Set 12 | paranagua
# Processing Record 33 of Set 12 | sparks
# Processing Record 34 of Set 12 | tefe
# Processing Record 35 of Set 12 | toguchin
# Processing Record 36 of Set 12 | marystown
# Processing Record 37 of Set 12 | brae
# Processing Record 38 of Set 12 | sembakung
# Processing Record 39 of Set 12 | tarauaca
# Processing Record 40 of Set 12 | gulshat
# City not found. Skipping...
# Processing Record 41 of Set 12 | werdau
# Processing Record 42 of Set 12 | port hedland
# Processing Record 43 of Set 12 | porto de moz
# Processing Record 44 of Set 12 | yauya
# Processing Record 45 of Set 12 | amazar
# Processing Record 46 of Set 12 | dawson creek
# Processing Record 47 of Set 12 | omboue
# Processing Record 48 of Set 12 | darhan
# Processing Record 49 of Set 12 | westerland
# Processing Record 50 of Set 12 | bacsay
# Processing Record 1 of Set 13 | lazaro cardenas
# Processing Record 2 of Set 13 | aksarka
# Processing Record 3 of Set 13 | kenora
# Processing Record 4 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 5 of Set 13 | talara
# Processing Record 6 of Set 13 | pocone
# Processing Record 7 of Set 13 | los llanos de aridane
# Processing Record 8 of Set 13 | mendi
# Processing Record 9 of Set 13 | mongo
# Processing Record 10 of Set 13 | bilma
# Processing Record 11 of Set 13 | port augusta
# Processing Record 12 of Set 13 | batasan
# Processing Record 13 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 14 of Set 13 | guiglo
# Processing Record 15 of Set 13 | muros
# Processing Record 16 of Set 13 | porbandar
# Processing Record 17 of Set 13 | waipawa
# Processing Record 18 of Set 13 | sibu
# Processing Record 19 of Set 13 | quatre cocos
# Processing Record 20 of Set 13 | new glasgow
# Processing Record 21 of Set 13 | peniche
# Processing Record 22 of Set 13 | leningradskiy
# Processing Record 23 of Set 13 | cayenne
# Processing Record 24 of Set 13 | ganzhou
# Processing Record 25 of Set 13 | acapulco
# Processing Record 26 of Set 13 | prince rupert
# Processing Record 27 of Set 13 | puerto pinasco
# City not found. Skipping...
# Processing Record 28 of Set 13 | beringovskiy
# Processing Record 29 of Set 13 | raudeberg
# Processing Record 30 of Set 13 | mezen
# Processing Record 31 of Set 13 | salalah
# Processing Record 32 of Set 13 | ibirama
# Processing Record 33 of Set 13 | mahebourg
# Processing Record 34 of Set 13 | tiarei
# Processing Record 35 of Set 13 | goba
# Processing Record 36 of Set 13 | aviles
# Processing Record 37 of Set 13 | iranshahr
# Processing Record 38 of Set 13 | lagoa
# Processing Record 39 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 40 of Set 13 | magdagachi
# Processing Record 41 of Set 13 | baihar
# Processing Record 42 of Set 13 | livingston
# Processing Record 43 of Set 13 | bryan
# Processing Record 44 of Set 13 | togitsu
# Processing Record 45 of Set 13 | markivka
# Processing Record 46 of Set 13 | bakel
# Processing Record 47 of Set 13 | braintree
# Processing Record 48 of Set 13 | henties bay
# Processing Record 49 of Set 13 | mamontovo
# Processing Record 50 of Set 13 | inuvik
# Processing Record 1 of Set 14 | sao jose da coroa grande
# Processing Record 2 of Set 14 | komsomolskiy
# Processing Record 3 of Set 14 | el sauzal
# Processing Record 4 of Set 14 | callander
# Processing Record 5 of Set 14 | shelburne
# Processing Record 6 of Set 14 | anloga
# Processing Record 7 of Set 14 | port moresby
# Processing Record 8 of Set 14 | uddevalla
# Processing Record 9 of Set 14 | halden
# Processing Record 10 of Set 14 | salinopolis
# Processing Record 11 of Set 14 | lac du bonnet
# Processing Record 12 of Set 14 | avera
# Processing Record 13 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 14 | batie
# Processing Record 16 of Set 14 | calahorra
# Processing Record 17 of Set 14 | verkhnyaya inta
# Processing Record 18 of Set 14 | inirida
# Processing Record 19 of Set 14 | evensk
# Processing Record 20 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 21 of Set 14 | amapa
# Processing Record 22 of Set 14 | sosnovo-ozerskoye
# Processing Record 23 of Set 14 | manaira
# Processing Record 24 of Set 14 | ambilobe
# Processing Record 25 of Set 14 | minsk
# Processing Record 26 of Set 14 | santa maria do para
# Processing Record 27 of Set 14 | coos bay
# Processing Record 28 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 29 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 30 of Set 14 | bardiyah
# Processing Record 31 of Set 14 | aix-les-bains
# Processing Record 32 of Set 14 | deputatskiy
# Processing Record 33 of Set 14 | kaizuka
# Processing Record 34 of Set 14 | nouakchott
# Processing Record 35 of Set 14 | millville
# Processing Record 36 of Set 14 | kedrovyy
# Processing Record 37 of Set 14 | trinidad
# Processing Record 38 of Set 14 | miri
# Processing Record 39 of Set 14 | choya
# Processing Record 40 of Set 14 | tessalit
# Processing Record 41 of Set 14 | qinhuangdao
# Processing Record 42 of Set 14 | auki
# Processing Record 43 of Set 14 | sao joao do paraiso
# Processing Record 44 of Set 14 | onufriyivka
# Processing Record 45 of Set 14 | roma
# Processing Record 46 of Set 14 | college
# Processing Record 47 of Set 14 | bemidji
# Processing Record 48 of Set 14 | pa sang
# Processing Record 49 of Set 14 | ciudad bolivar
# Processing Record 50 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 15 | katherine
# Processing Record 2 of Set 15 | daru
# Processing Record 3 of Set 15 | pachino
# Processing Record 4 of Set 15 | sabang
# Processing Record 5 of Set 15 | farah
# Processing Record 6 of Set 15 | mme
# City not found. Skipping...
# Processing Record 7 of Set 15 | fare
# Processing Record 8 of Set 15 | andros town
# Processing Record 9 of Set 15 | colombia
# Processing Record 10 of Set 15 | san policarpo
# Processing Record 11 of Set 15 | ayagoz
# Processing Record 12 of Set 15 | ixtapa
# Processing Record 13 of Set 15 | buenaventura
# Processing Record 14 of Set 15 | mbanza-ngungu
# Processing Record 15 of Set 15 | karratha
# Processing Record 16 of Set 15 | awjilah
# Processing Record 17 of Set 15 | rairangpur
# Processing Record 18 of Set 15 | amos
# Processing Record 19 of Set 15 | akhmeta
# Processing Record 20 of Set 15 | kinkala
# Processing Record 21 of Set 15 | sistranda
# Processing Record 22 of Set 15 | mogadishu
# Processing Record 23 of Set 15 | vila
# Processing Record 24 of Set 15 | saint-leu
# Processing Record 25 of Set 15 | shestakovo
# Processing Record 26 of Set 15 | bonavista
# Processing Record 27 of Set 15 | vanimo
# Processing Record 28 of Set 15 | bentiu
# Processing Record 29 of Set 15 | kuytun
# Processing Record 30 of Set 15 | margate
# Processing Record 31 of Set 15 | florianopolis
# Processing Record 32 of Set 15 | vilyuysk
# Processing Record 33 of Set 15 | izhma
# Processing Record 34 of Set 15 | bullingen
# City not found. Skipping...
# Processing Record 35 of Set 15 | menongue
# Processing Record 36 of Set 15 | belmonte
# Processing Record 37 of Set 15 | vegreville
# Processing Record 38 of Set 15 | guaruja
# Processing Record 39 of Set 15 | kem
# Processing Record 40 of Set 15 | pozo colorado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Reorder Columns
new_col_ord = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_col_ord]

# %%
# Format DataFrame
city_data_df['Lat'] = city_data_df['Lat'].map('{:,.2f}'.format)
city_data_df['Lng'] = city_data_df['Lng'].map('{:,.2f}'.format)
city_data_df['Max Temp'] = city_data_df['Max Temp'].map('{:,.2f}'.format)
city_data_df['Wind Speed'] = city_data_df['Wind Speed'].map('{:,.2f}'.format)

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
